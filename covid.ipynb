# %% [markdown]
# # 1. Exploratory data Analysis
# ### Objectif:
# ### Checklist de base
# Analyse de Forme:
#  - variable targeet:
#  - lignes et colonnes:
#  - types de variables:
#  - analyse des valeurs manquantes:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
